# %% [markdown]
# # Academy Awards Ratings Analysis Project

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Academy Award Dataset

# %%
#import dataset 
#kaggle URL https://www.kaggle.com/datasets/unanimad/the-oscar-award?resource=download
full_oscars = pd.read_csv(r"C:\Users\chlot\OneDrive\Desktop\the_oscars.csv")

# %%
full_oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10395 entries, 0 to 10394
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      10395 non-null  int64
#  1   year_ceremony  10395 non-null  int64
#  2   ceremony       10395 non-null  int64
#  3   category       10395 non-null  object
#  4   name           10395 non-null  object
#  5   film           10091 non-null  object
#  6   winner         10395 non-null  bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 497.5+ KB

# %%
full_oscars.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
#filtering out the columns ceremony because the year of the ceremony is what counts for this analysis. 
oscars = full_oscars[["year_film", "year_ceremony", "category", "name", "film", "winner"]]

# %%
oscars.head()
# Out:
#    year_film  year_ceremony category                 name              film  \
# 0       1927           1928    ACTOR  Richard Barthelmess         The Noose
# 1       1927           1928    ACTOR        Emil Jannings  The Last Command
# 2       1927           1928  ACTRESS       Louise Dresser   A Ship Comes In
# 3       1927           1928  ACTRESS         Janet Gaynor        7th Heaven
# 4       1927           1928  ACTRESS       Gloria Swanson    Sadie Thompson
#
#    winner
# 0   False
# 1    True
# 2   False
# 3    True
# 4   False

# %% [markdown]
# ### Analysis

# %%
winners = oscars[oscars["winner"] == True]

# %%
winners
# Out:
#        year_film  year_ceremony                          category  \
# 1           1927           1928                             ACTOR
# 3           1927           1928                           ACTRESS
# 6           1927           1928                     ART DIRECTION
# 9           1927           1928                    CINEMATOGRAPHY
# 10          1927           1928                    CINEMATOGRAPHY
# ...          ...            ...                               ...
# 10390       2019           2020     WRITING (Original Screenplay)
# 10391       2019           2020  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020                    HONORARY AWARD
# 10393       2019           2020                    HONORARY AWARD
# 10394       2019           2020                    HONORARY AWARD
#
#                                                     name              film  \
# 1                                          Emil Jannings  The Last Command
# 3                                           Janet Gaynor        7th Heaven
# 6                                William Cameron Menzies         The Dove;
# 9                                         Charles Rosher           Sunrise
# 10                                           Karl Struss           Sunrise
# ...                                                  ...               ...
# 10390  Screenplay by Bong Joon Ho, Han Jin Won; Story...          Parasite
# 10391                                        Geena Davis               NaN
# 10392                                        David Lynch               NaN
# 10393                                          Wes Studi               NaN
# 10394                                    Lina Wertmüller               NaN
#
#        winner
# 1        True
# 3        True
# 6        True
# 9        True
# 10       True
# ...       ...
# 10390    True
# 10391    True
# 10392    True
# 10393    True
# 10394    True
#
# [2357 rows x 6 columns]

# %%
nominated = oscars[oscars["winner"] == False]

# %%
#what are the most nominted movies
oscars[["film"]].value_counts()
# Out:
# film
# A Star Is Born                 25
# Titanic                        16
# Moulin Rouge                   15
# Mutiny on the Bounty           15
# Little Women                   14
#                                ..
# Let's Make Love                 1
# Let's Pollute                   1
# Lethal Weapon                   1
# Lethal Weapon 2                 1
# Éramos Pocos (One Too Many)     1
# Length: 4833, dtype: int64

# %%
#The results show that A Star is Born was nominated far more than any other movie and seems like an outlier.
#There might be more than one film with that name in the list.

# %% [markdown]
# #### Outlier Analysis

# %%
star_born = oscars[oscars["film"] == "A Star Is Born"]
star_born
# Out:
#        year_film  year_ceremony  \
# 523         1937           1938
# 534         1937           1938
# 558         1937           1938
# 573         1937           1938
# 607         1937           1938
# 634         1937           1938
# 639         1937           1938
# 2888        1954           1955
# 2896        1954           1955
# 2913        1954           1955
# 2933        1954           1955
# 2958        1954           1955
# 2963        1954           1955
# 5434        1976           1977
# 5472        1976           1977
# 5476        1976           1977
# 5495        1976           1977
# 10143       2018           2019
# 10149       2018           2019
# 10155       2018           2019
# 10171       2018           2019
# 10213       2018           2019
# 10221       2018           2019
# 10247       2018           2019
# 10257       2018           2019
#
#                                                 category  \
# 523                                                ACTOR
# 534                                              ACTRESS
# 558                                   ASSISTANT DIRECTOR
# 573                                            DIRECTING
# 607                               OUTSTANDING PRODUCTION
# 634                             WRITING (Original Story)
# 639                                 WRITING (Screenplay)
# 2888                                               ACTOR
# 2896                                             ACTRESS
# 2913                               ART DIRECTION (Color)
# 2933                              COSTUME DESIGN (Color)
# 2958                MUSIC (Scoring of a Musical Picture)
# 2963                                        MUSIC (Song)
# 5434                                      CINEMATOGRAPHY
# 5472   MUSIC (Original Song Score and Its Adaptation ...
# 5476                               MUSIC (Original Song)
# 5495                                               SOUND
# 10143                            ACTOR IN A LEADING ROLE
# 10149                         ACTOR IN A SUPPORTING ROLE
# 10155                          ACTRESS IN A LEADING ROLE
# 10171                                     CINEMATOGRAPHY
# 10213                              MUSIC (Original Song)
# 10221                                       BEST PICTURE
# 10247                                       SOUND MIXING
# 10257                       WRITING (Adapted Screenplay)
#
#                                                     name            film  \
# 523                                        Fredric March  A Star Is Born
# 534                                         Janet Gaynor  A Star Is Born
# 558                                          Eric Stacey  A Star Is Born
# 573                                      William Wellman  A Star Is Born
# 607                      Selznick International Pictures  A Star Is Born
# 634                    William A. Wellman, Robert Carson  A Star Is Born
# 639         Dorothy Parker, Alan Campbell, Robert Carson  A Star Is Born
# 2888                                         James Mason  A Star Is Born
# 2896                                        Judy Garland  A Star Is Born
# 2913   Art Direction:  Malcolm Bert, Gene Allen, Iren...  A Star Is Born
# 2933          Jean Louis, Mary Ann Nyberg, Irene Sharaff  A Star Is Born
# 2958                                        Ray Heindorf  A Star Is Born
# 2963       Music by Harold Arlen; Lyrics by Ira Gershwin  A Star Is Born
# 5434                                      Robert Surtees  A Star Is Born
# 5472                  Adaptation Score by Roger Kellaway  A Star Is Born
# 5476   Music by Barbra Streisand; Lyrics by Paul Will...  A Star Is Born
# 5495   Robert Knudson, Dan Wallin, Robert Glass, Tom ...  A Star Is Born
# 10143                                     Bradley Cooper  A Star Is Born
# 10149                                        Sam Elliott  A Star Is Born
# 10155                                          Lady Gaga  A Star Is Born
# 10171                                  Matthew Libatique  A Star Is Born
# 10213  Music and Lyric by Lady Gaga, Mark Ronson, Ant...  A Star Is Born
# 10221  Bill Gerber, Bradley Cooper and Lynette Howell...  A Star Is Born
# 10247  Tom Ozanich, Dean Zupancic, Jason Ruder and St...  A Star Is Born
# 10257  Screenplay by Eric Roth and Bradley Cooper & W...  A Star Is Born
#
#        winner
# 523     False
# 534     False
# 558     False
# 573     False
# 607     False
# 634      True
# 639     False
# 2888    False
# 2896    False
# 2913    False
# 2933    False
# 2958    False
# 2963    False
# 5434    False
# 5472    False
# 5476     True
# 5495    False
# 10143   False
# 10149   False
# 10155   False
# 10171   False
# 10213    True
# 10221   False
# 10247   False
# 10257   False

# %%
#There are 4 different A Star Is Born Movies: 1938, 1955, 1977 and 2019

# %%
#adding the release year to the table helps differentiate the films from different years with the same title
count = oscars[["film", "year_film"]].value_counts()

# %%
#another way to find the list of individual movies would be using .drop_duplicates
unique_movies = oscars.drop_duplicates(subset=["film", "year_film"])
unique_movies
# Out:
#        year_film  year_ceremony                          category  \
# 0           1927           1928                             ACTOR
# 1           1927           1928                             ACTOR
# 2           1927           1928                           ACTRESS
# 3           1927           1928                           ACTRESS
# 4           1927           1928                           ACTRESS
# ...          ...            ...                               ...
# 10371       2019           2020                      SOUND MIXING
# 10376       2019           2020                    VISUAL EFFECTS
# 10378       2019           2020                    VISUAL EFFECTS
# 10386       2019           2020     WRITING (Original Screenplay)
# 10391       2019           2020  JEAN HERSHOLT HUMANITARIAN AWARD
#
#                                                     name               film  \
# 0                                    Richard Barthelmess          The Noose
# 1                                          Emil Jannings   The Last Command
# 2                                         Louise Dresser    A Ship Comes In
# 3                                           Janet Gaynor         7th Heaven
# 4                                         Gloria Swanson     Sadie Thompson
# ...                                                  ...                ...
# 10371          Gary Rydstrom, Tom Johnson and Mark Ulano           Ad Astra
# 10376  Dan DeLeeuw, Russell Earl, Matt Aitken and Dan...  Avengers: Endgame
# 10378  Robert Legato, Adam Valdez, Andrew R. Jones an...      The Lion King
# 10386                            Written by Rian Johnson         Knives Out
# 10391                                        Geena Davis                NaN
#
#        winner
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# ...       ...
# 10371   False
# 10376   False
# 10378   False
# 10386   False
# 10391    True
#
# [5024 rows x 6 columns]

# %%
#Certain awards are givin out without a movie related to it, let's drop those rows
unique_movies.dropna()
# Out:
#        year_film  year_ceremony                       category  \
# 0           1927           1928                          ACTOR
# 1           1927           1928                          ACTOR
# 2           1927           1928                        ACTRESS
# 3           1927           1928                        ACTRESS
# 4           1927           1928                        ACTRESS
# ...          ...            ...                            ...
# 10365       2019           2020       SHORT FILM (Live Action)
# 10371       2019           2020                   SOUND MIXING
# 10376       2019           2020                 VISUAL EFFECTS
# 10378       2019           2020                 VISUAL EFFECTS
# 10386       2019           2020  WRITING (Original Screenplay)
#
#                                                     name               film  \
# 0                                    Richard Barthelmess          The Noose
# 1                                          Emil Jannings   The Last Command
# 2                                         Louise Dresser    A Ship Comes In
# 3                                           Janet Gaynor         7th Heaven
# 4                                         Gloria Swanson     Sadie Thompson
# ...                                                  ...                ...
# 10365                                    Delphine Girard           A Sister
# 10371          Gary Rydstrom, Tom Johnson and Mark Ulano           Ad Astra
# 10376  Dan DeLeeuw, Russell Earl, Matt Aitken and Dan...  Avengers: Endgame
# 10378  Robert Legato, Adam Valdez, Andrew R. Jones an...      The Lion King
# 10386                            Written by Rian Johnson         Knives Out
#
#        winner
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# ...       ...
# 10365   False
# 10371   False
# 10376   False
# 10378   False
# 10386   False
#
# [4934 rows x 6 columns]

# %%
#this confirms that 4934 movies were nominated across all academy award ceremonies

# %% [markdown]
# #### Analysis of the highest winning movies

# %%
biggest_winners = winners[["film", "year_film"]].value_counts()
biggest_winners
# Out:
# film                                           year_film
# Titanic                                        1997         11
# Ben-Hur                                        1959         11
# The Lord of the Rings: The Return of the King  2003         11
# West Side Story                                1961         10
# The Last Emperor                               1987          9
#                                                             ..
# Knighty Knight Bugs                            1958          1
# Kokoda Front Line!                             1942          1
# Kolya                                          1996          1
# Kon-Tiki                                       1951          1
# tom thumb                                      1958          1
# Length: 1286, dtype: int64

# %%
df_winners = pd.DataFrame(biggest_winners)

# %%
#slicing the top 10
df_winners[:10]
# Out:
#                                                           0
# film                                          year_film
# Titanic                                       1997       11
# Ben-Hur                                       1959       11
# The Lord of the Rings: The Return of the King 2003       11
# West Side Story                               1961       10
# The Last Emperor                              1987        9
# Gigi                                          1958        9
# The English Patient                           1996        9
# Slumdog Millionaire                           2008        8
# Cabaret                                       1972        8
# On the Waterfront                             1954        8

# %% [markdown]
# ### Joining the top 10 with the original dataset

# %%
top10 = df_winners[:10].merge(oscars, on=["year_film", "film"], how="inner")
top10
# Out:
#      year_film               film   0  year_ceremony  \
# 0         1997            Titanic  11           1998
# 1         1997            Titanic  11           1998
# 2         1997            Titanic  11           1998
# 3         1997            Titanic  11           1998
# 4         1997            Titanic  11           1998
# ..         ...                ...  ..            ...
# 105       1954  On the Waterfront   8           1955
# 106       1954  On the Waterfront   8           1955
# 107       1954  On the Waterfront   8           1955
# 108       1954  On the Waterfront   8           1955
# 109       1954  On the Waterfront   8           1955
#
#                                               category  \
# 0                            ACTRESS IN A LEADING ROLE
# 1                         ACTRESS IN A SUPPORTING ROLE
# 2                                        ART DIRECTION
# 3                                       CINEMATOGRAPHY
# 4                                       COSTUME DESIGN
# ..                                                 ...
# 105                                          DIRECTING
# 106                                       FILM EDITING
# 107  MUSIC (Music Score of a Dramatic or Comedy Pic...
# 108                                BEST MOTION PICTURE
# 109                     WRITING (Story and Screenplay)
#
#                                                   name  winner
# 0                                         Kate Winslet   False
# 1                                        Gloria Stuart   False
# 2    Art Direction:  Peter Lamont;  Set Decoration:...    True
# 3                                    Russell Carpenter    True
# 4                                     Deborah L. Scott    True
# ..                                                 ...     ...
# 105                                         Elia Kazan    True
# 106                                       Gene Milford    True
# 107                                  Leonard Bernstein   False
# 108                              Sam Spiegel, Producer    True
# 109                                     Budd Schulberg    True
#
# [110 rows x 7 columns]

# %%
top10[top10["category"] == "BEST PICTURE"]
# Out:
#     year_film                                           film   0  \
# 10       1997                                        Titanic  11
# 33       2003  The Lord of the Rings: The Return of the King  11
# 54       1987                               The Last Emperor   9
# 75       1996                            The English Patient   9
# 84       2008                            Slumdog Millionaire   8
# 95       1972                                        Cabaret   8
#
#     year_ceremony      category  \
# 10           1998  BEST PICTURE
# 33           2004  BEST PICTURE
# 54           1988  BEST PICTURE
# 75           1997  BEST PICTURE
# 84           2009  BEST PICTURE
# 95           1973  BEST PICTURE
#
#                                                  name  winner
# 10            James Cameron and Jon Landau, Producers    True
# 33  Barrie M. Osborne, Peter Jackson and Fran Wals...    True
# 54                            Jeremy Thomas, Producer    True
# 75                              Saul Zaentz, Producer    True
# 84                         Christian Colson, Producer    True
# 95                                 Cy Feuer, Producer   False

# %%
top10[top10["category"] == "BEST PICTURE"]
# Out:
#     year_film                                           film   0  \
# 10       1997                                        Titanic  11
# 33       2003  The Lord of the Rings: The Return of the King  11
# 54       1987                               The Last Emperor   9
# 75       1996                            The English Patient   9
# 84       2008                            Slumdog Millionaire   8
# 95       1972                                        Cabaret   8
#
#     year_ceremony      category  \
# 10           1998  BEST PICTURE
# 33           2004  BEST PICTURE
# 54           1988  BEST PICTURE
# 75           1997  BEST PICTURE
# 84           2009  BEST PICTURE
# 95           1973  BEST PICTURE
#
#                                                  name  winner
# 10            James Cameron and Jon Landau, Producers    True
# 33  Barrie M. Osborne, Peter Jackson and Fran Wals...    True
# 54                            Jeremy Thomas, Producer    True
# 75                              Saul Zaentz, Producer    True
# 84                         Christian Colson, Producer    True
# 95                                 Cy Feuer, Producer   False

# %% [markdown]
# ## IMDB Dataset

# %%
#importing IMDB dataset to look at ratings for oscar movies
full_imdb = pd.read_csv(r"C:\Users\chlot\OneDrive\Desktop\imdb_top_1000.csv")

# %%
full_imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
#removing unneeded columns, as I am mostly interesteed in the ratings
imdb = full_imdb[["Series_Title", "Released_Year", "Runtime", "Genre", "IMDB_Rating", "Meta_score", "Director", "Gross"]]

# %%
imdb.head()
# Out:
#                Series_Title Released_Year  Runtime                 Genre  \
# 0  The Shawshank Redemption          1994  142 min                 Drama
# 1             The Godfather          1972  175 min          Crime, Drama
# 2           The Dark Knight          2008  152 min  Action, Crime, Drama
# 3    The Godfather: Part II          1974  202 min          Crime, Drama
# 4              12 Angry Men          1957   96 min          Crime, Drama
#
#    IMDB_Rating  Meta_score              Director        Gross
# 0          9.3        80.0        Frank Darabont   28,341,469
# 1          9.2       100.0  Francis Ford Coppola  134,966,411
# 2          9.0        84.0     Christopher Nolan  534,858,444
# 3          9.0        90.0  Francis Ford Coppola   57,300,000
# 4          9.0        96.0          Sidney Lumet    4,360,000

# %%
#gain some information about the dataset, that includes the top 1000 movies on IMDB
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   object
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Meta_score     843 non-null    float64
#  6   Director       1000 non-null   object
#  7   Gross          831 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# ### Joining Academy Award and IMDB datasets

# %%
merged = oscars.merge(imdb, left_on=["film"], right_on=["Series_Title"])
merged
# Out:
#       year_film  year_ceremony                       category  \
# 0          1929           1930                 CINEMATOGRAPHY
# 1          1929           1930                      DIRECTING
# 2          1929           1930         OUTSTANDING PRODUCTION
# 3          1929           1930                        WRITING
# 4          1932           1933                      DIRECTING
# ...         ...            ...                            ...
# 2257       2019           2020                   BEST PICTURE
# 2258       2019           2020                  SOUND EDITING
# 2259       2019           2020                   SOUND MIXING
# 2260       2019           2020                 VISUAL EFFECTS
# 2261       2019           2020  WRITING (Original Screenplay)
#
#                                                    name  \
# 0                                       (Arthur Edeson)
# 1                                       Lewis Milestone
# 2                                             Universal
# 3     (George Abbott), (Maxwell Anderson), (Del Andr...
# 4                                          George Cukor
# ...                                                 ...
# 2257  Peter Chernin, Jenno Topping and James Mangold...
# 2258                                   Donald Sylvester
# 2259  Paul Massey, David Giammarco and Steven A. Morrow
# 2260  Dan DeLeeuw, Russell Earl, Matt Aitken and Dan...
# 2261                            Written by Rian Johnson
#
#                                 film  winner                    Series_Title  \
# 0     All Quiet on the Western Front   False  All Quiet on the Western Front
# 1     All Quiet on the Western Front    True  All Quiet on the Western Front
# 2     All Quiet on the Western Front    True  All Quiet on the Western Front
# 3     All Quiet on the Western Front   False  All Quiet on the Western Front
# 4                       Little Women   False                    Little Women
# ...                              ...     ...                             ...
# 2257                  Ford v Ferrari   False                  Ford v Ferrari
# 2258                  Ford v Ferrari    True                  Ford v Ferrari
# 2259                  Ford v Ferrari   False                  Ford v Ferrari
# 2260               Avengers: Endgame   False               Avengers: Endgame
# 2261                      Knives Out   False                      Knives Out
#
#      Released_Year  Runtime                     Genre  IMDB_Rating  \
# 0             1930  152 min                Drama, War          8.0
# 1             1930  152 min                Drama, War          8.0
# 2             1930  152 min                Drama, War          8.0
# 3             1930  152 min                Drama, War          8.0
# 4             2019  135 min            Drama, Romance          7.8
# ...            ...      ...                       ...          ...
# 2257          2019  152 min  Action, Biography, Drama          8.1
# 2258          2019  152 min  Action, Biography, Drama          8.1
# 2259          2019  152 min  Action, Biography, Drama          8.1
# 2260          2019  181 min  Action, Adventure, Drama          8.4
# 2261          2019  130 min      Comedy, Crime, Drama          7.9
#
#       Meta_score         Director        Gross
# 0           91.0  Lewis Milestone    3,270,000
# 1           91.0  Lewis Milestone    3,270,000
# 2           91.0  Lewis Milestone    3,270,000
# 3           91.0  Lewis Milestone    3,270,000
# 4           91.0     Greta Gerwig  108,101,214
# ...          ...              ...          ...
# 2257        81.0    James Mangold  117,624,028
# 2258        81.0    James Mangold  117,624,028
# 2259        81.0    James Mangold  117,624,028
# 2260        78.0    Anthony Russo  858,373,000
# 2261        82.0     Rian Johnson  165,359,751
#
# [2262 rows x 14 columns]

# %%
merged.drop(["Released_Year", "Series_Title"], axis=1)
# Out:
#       year_film  year_ceremony                       category  \
# 0          1929           1930                 CINEMATOGRAPHY
# 1          1929           1930                      DIRECTING
# 2          1929           1930         OUTSTANDING PRODUCTION
# 3          1929           1930                        WRITING
# 4          1932           1933                      DIRECTING
# ...         ...            ...                            ...
# 2257       2019           2020                   BEST PICTURE
# 2258       2019           2020                  SOUND EDITING
# 2259       2019           2020                   SOUND MIXING
# 2260       2019           2020                 VISUAL EFFECTS
# 2261       2019           2020  WRITING (Original Screenplay)
#
#                                                    name  \
# 0                                       (Arthur Edeson)
# 1                                       Lewis Milestone
# 2                                             Universal
# 3     (George Abbott), (Maxwell Anderson), (Del Andr...
# 4                                          George Cukor
# ...                                                 ...
# 2257  Peter Chernin, Jenno Topping and James Mangold...
# 2258                                   Donald Sylvester
# 2259  Paul Massey, David Giammarco and Steven A. Morrow
# 2260  Dan DeLeeuw, Russell Earl, Matt Aitken and Dan...
# 2261                            Written by Rian Johnson
#
#                                 film  winner  Runtime  \
# 0     All Quiet on the Western Front   False  152 min
# 1     All Quiet on the Western Front    True  152 min
# 2     All Quiet on the Western Front    True  152 min
# 3     All Quiet on the Western Front   False  152 min
# 4                       Little Women   False  135 min
# ...                              ...     ...      ...
# 2257                  Ford v Ferrari   False  152 min
# 2258                  Ford v Ferrari    True  152 min
# 2259                  Ford v Ferrari   False  152 min
# 2260               Avengers: Endgame   False  181 min
# 2261                      Knives Out   False  130 min
#
#                          Genre  IMDB_Rating  Meta_score         Director  \
# 0                   Drama, War          8.0        91.0  Lewis Milestone
# 1                   Drama, War          8.0        91.0  Lewis Milestone
# 2                   Drama, War          8.0        91.0  Lewis Milestone
# 3                   Drama, War          8.0        91.0  Lewis Milestone
# 4               Drama, Romance          7.8        91.0     Greta Gerwig
# ...                        ...          ...         ...              ...
# 2257  Action, Biography, Drama          8.1        81.0    James Mangold
# 2258  Action, Biography, Drama          8.1        81.0    James Mangold
# 2259  Action, Biography, Drama          8.1        81.0    James Mangold
# 2260  Action, Adventure, Drama          8.4        78.0    Anthony Russo
# 2261      Comedy, Crime, Drama          7.9        82.0     Rian Johnson
#
#             Gross
# 0       3,270,000
# 1       3,270,000
# 2       3,270,000
# 3       3,270,000
# 4     108,101,214
# ...           ...
# 2257  117,624,028
# 2258  117,624,028
# 2259  117,624,028
# 2260  858,373,000
# 2261  165,359,751
#
# [2262 rows x 12 columns]

# %% [markdown]
# ### Analysis of merged table

# %%
#lowerst and higest rated movie 
merged["Meta_score"].min()
# Out:
# 28.0

# %%
merged[merged["Meta_score"] == 28]
# Out:
#       year_film  year_ceremony                 category       name      film  \
# 1477       2001           2002  ACTOR IN A LEADING ROLE  Sean Penn  I Am Sam
#
#       winner Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 1477   False     I Am Sam          2001  132 min  Drama          7.7
#
#       Meta_score       Director       Gross
# 1477        28.0  Jessie Nelson  40,311,852

# %%
merged["Meta_score"].max()
# Out:
# 100.0

# %%
merged["IMDB_Rating"].max()
# Out:
# 9.3

# %% [markdown]
# ### Visualizations

# %%
sns.set(color_codes=True)
sns.displot(merged["IMDB_Rating"], bins=10, color= "limegreen")
sns.set_style("darkgrid")
plt.xlabel("IMDB Rating")
plt.ylabel("Number of Movies")
plt.title ("IMDB ratings for Oscar nominated movies")
plt.show()

# %%
fig, ax= plt.subplots()
ax.hist(merged["Meta_score"])
ax.set_xlabel("Meta Score")
ax.set_ylabel("Number of Movies")
ax.set_title("Meta Scores for Oscar nominated Movies")
ax.axvline(x=28, label="Worst Meta Score for Oscar nominated Movie", linestyle= "--", color="r")
plt.show()

# %%
#ratings for the top10
top10_rating = df_winners[:10].merge(imdb, how="inner", left_on=["film"], right_on=["Series_Title"])

# %%
top10_rating
#The imdb ratings and Meta-Scores of the movies with the most awards
# Out:
#     0                                   Series_Title Released_Year  Runtime  \
# 0  11                                        Titanic          1997  194 min
# 1  11                                        Ben-Hur          1959  212 min
# 2  11  The Lord of the Rings: The Return of the King          2003  201 min
# 3   9                               The Last Emperor          1987  163 min
# 4   8                            Slumdog Millionaire          2008  120 min
# 5   8                                        Cabaret          1972  124 min
# 6   8                              On the Waterfront          1954  108 min
#
#                        Genre  IMDB_Rating  Meta_score             Director  \
# 0             Drama, Romance          7.8        75.0        James Cameron
# 1  Adventure, Drama, History          8.1        90.0        William Wyler
# 2   Action, Adventure, Drama          8.9        94.0        Peter Jackson
# 3  Biography, Drama, History          7.7        76.0  Bernardo Bertolucci
# 4             Drama, Romance          8.0        84.0          Danny Boyle
# 5      Drama, Music, Musical          7.8        80.0            Bob Fosse
# 6     Crime, Drama, Thriller          8.1        91.0           Elia Kazan
#
#          Gross
# 0  659,325,379
# 1   74,700,000
# 2  377,845,905
# 3   43,984,230
# 4  141,319,928
# 5   42,765,000
# 6    9,600,000

# %%
sns.barplot(top10_rating["IMDB_Rating"], top10_rating["Series_Title"], color= "m")
plt.xlabel("IMDB Rating")
plt.ylabel("Movie Title")
plt.title ("IMDB ratings for the highest awarded movies")
plt.show()
# Out:
# C:\Users\chlot\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(top10_rating["Meta_score"], top10_rating["Series_Title"], color= "orange")
plt.xlabel("Meta Score")
plt.ylabel("Movie Title")
plt.title ("Meta score ratings for the highest awarded movies")
plt.show()
# Out:
# C:\Users\chlot\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
